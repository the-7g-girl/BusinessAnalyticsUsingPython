# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
y=np.cos(x)
plt.plot(x,y)

# %%
dict = {'A':25, 'B':60, 'C':40, 'D':100, 'E':80, 'F':50}
for i, key in enumerate(dict):
    plt.bar(i, dict[key])

# %%
plt.figure(figsize = (3,3)) # Size of the plot in inches
x = [30, 20, 5,15] 
labels = ['Chocolate', 'Mango', 'Pista','Watermellon']
plt.pie(x, labels = labels)
plt.show()
