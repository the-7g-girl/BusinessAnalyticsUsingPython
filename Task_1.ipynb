# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_excel("/content/Task_Data.xlsx")
df
# Out:
#     ID   Team Country     NameF      NameL  Weight Height        DOB  \
# 0   15  Women  Canada  Jocelyne   Larocque   139.0    5'6 1988-05-19
# 1   16  Women  Canada  Brigette  Lacquette   180.0    5'6 1992-10-11
# 2   17  Women  Canada  Lauriane    Rougeau   167.0    5'8 1990-04-12
# 3   18  Women  Canada     Laura    Fortino   137.0    5'4 1991-01-30
# 4   19  Women  Canada   Meaghan  Mikkelson   139.0    5'9 1985-01-04
# ..  ..    ...     ...       ...        ...     ...    ...        ...
# 91  68  Women     USA      Alex     Rigsby   150.0    5'7 1992-01-03
# 92  69  Women     USA    Maddie     Rooney     NaN    5'5 1997-07-07
# 93  84    Men     USA     David     Leggio   185.0    6'0 1984-07-31
# 94  86    Men     USA   Brandon    Maxwell   196.0    6'1 1991-03-22
# 95  96    Men     USA      Ryan   Zapolski   203.0    6'0 1986-11-11
#
#         Hometown   Prov      Pos  Age  HeightFt  HtIn  BMI
# 0      Ste. Anne   Man.  Defence   34  5.500000    66   22
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ID        96 non-null     int64
#  1   Team      96 non-null     object
#  2   Country   96 non-null     object
#  3   NameF     96 non-null     object
#  4   NameL     96 non-null     object
#  5   Weight    91 non-null     float64
#  6   Height    96 non-null     object
#  7   DOB       90 non-null     datetime64[ns]
#  8   Hometown  96 non-null     object
#  9   Prov      96 non-null     object
#  10  Pos       96 non-null     object
#  11  Age       96 non-null     int64
#  12  HeightFt  96 non-null     float64
#  13  HtIn      96 non-null     int64
#  14  BMI       96 non-null     int64
# dtypes: datetime64[ns](1), float64(2), int64(4), object(8)
# memory usage: 11.4+ KB

# %%
df.dropna(subset=['Weight'])
# Out:
#     ID   Team Country     NameF      NameL  Weight Height        DOB  \
# 0   15  Women  Canada  Jocelyne   Larocque   139.0    5'6 1988-05-19
# 1   16  Women  Canada  Brigette  Lacquette   180.0    5'6 1992-10-11
# 2   17  Women  Canada  Lauriane    Rougeau   167.0    5'8 1990-04-12
# 3   18  Women  Canada     Laura    Fortino   137.0    5'4 1991-01-30
# 4   19  Women  Canada   Meaghan  Mikkelson   139.0    5'9 1985-01-04
# ..  ..    ...     ...       ...        ...     ...    ...        ...
# 90  57  Women     USA    Nicole    Hensley   155.0    5'7 1994-06-23
# 91  68  Women     USA      Alex     Rigsby   150.0    5'7 1992-01-03
# 93  84    Men     USA     David     Leggio   185.0    6'0 1984-07-31
# 94  86    Men     USA   Brandon    Maxwell   196.0    6'1 1991-03-22
# 95  96    Men     USA      Ryan   Zapolski   203.0    6'0 1986-11-11
#
#         Hometown   Prov      Pos  Age  HeightFt  HtIn  BMI
# 0      Ste. Anne   Man.  Defence   34  5.500000    66   22
# ...

# %%
df["DOB"]=df["DOB"].fillna(value="na")

# %%
df.Pos.unique()
# Out:
# array(['Defence', 'Forward', 'Goalie'], dtype=object)

# %%
grouping1=df.groupby('Pos')
grouping1.first()
# Out:
#          ID   Team Country     NameF     NameL  Weight Height        DOB  \
# Pos
# Defence  15  Women  Canada  Jocelyne  Larocque   139.0    5'6 1988-05-19
# Forward   1  Women  Canada    Meghan    Agosta   148.0    5'7 1987-02-12
# Goalie   21  Women  Canada   Shannon  Szabados   146.0    5'8 1986-08-06
#
#           Hometown   Prov  Age  HeightFt  HtIn  BMI
# Pos
# Defence  Ste. Anne   Man.   34  5.500000    66   22
# Forward    Ruthven   Ont.   35  5.583333    67   23
# Goalie    Edmonton  Alta.   35  5.666667    68   22

# %%
grouping2=df.groupby('Team')
women=grouping2.get_group('Women')
men=grouping2.get_group('Men')

# %%
women
# Out:
#     ID   Team Country         NameF               NameL  Weight Height  \
# 0   15  Women  Canada      Jocelyne            Larocque   139.0    5'6
# 1   16  Women  Canada      Brigette           Lacquette   180.0    5'6
# 2   17  Women  Canada      Lauriane             Rougeau   167.0    5'8
# 3   18  Women  Canada         Laura             Fortino   137.0    5'4
# 4   19  Women  Canada       Meaghan           Mikkelson   139.0    5'9
# 5   20  Women  Canada        Renata                Fast   144.0    5'6
# 14  49  Women     USA         Cayla              Barnes   145.0    5'1
# 15  50  Women     USA         Kacey             Bellamy   145.0    5'7
# 16  56  Women     USA          Kali            Flanagan   142.0    5'4
# 17  58  Women     USA         Megan              Keller   160.0   5'11
# 18  64  Women     USA        Sidney               Morin   140.0    5'5
# 20  71  Women     USA           Lee           Stecklein   175.0    6'0
# ...

# %%
men
# Out:
#     ID Team Country       NameF        NameL  Weight Height  \
# 6   38  Men  Canada        Karl     Stollery   181.0   5'11
# 7   39  Men  Canada       Chris          Lee   187.0    6'0
# 8   40  Men  Canada        Chay      Genoway   170.0    5'9
# 9   41  Men  Canada  Marc-Andre     Gragnani   205.0    6'3
# 10  42  Men  Canada      Stefan      Elliott   190.0    6'1
# 11  43  Men  Canada        Cody     Goloubef   200.0    6'1
# 12  44  Men  Canada         Mat     Robinson   185.0   5'10
# 13  45  Men  Canada       Maxim       Noreau   198.0    6'0
# 22  74  Men     USA    Jonathan         Blum   195.0    6'1
# 23  75  Men     USA        Will       Borgen   195.0    6'2
# 24  79  Men     USA        Matt       Gilroy   200.0    6'1
# 25  82  Men     USA        Ryan    Gunderson   170.0    5'9
# 26  90  Men     USA       Bobby  Sanguinetti   190.0    6'2
# 27  94  Men     USA        Noah        Welch   215.0    6'4
# 28  95  Men     USA       James   Wisniewski   205.0    6'0
# ...

# %%
#median height of male players
med_ht_men=men['Height'].median()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/nanops.py in nanmedian(values, axis, skipna, mask)
#     719         try:
# --> 720             values = values.astype("f8")
#     721         except ValueError as err:
#
# ValueError: could not convert string to float: "5'11"
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-3d1f4f6e948e> in <module>()
#       1 #median height of male players
# ----> 2 med_ht_men=men['Height'].median()
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in median(self, axis, skipna, level, numeric_only, **kwargs)
#   10800             self, axis=None, skipna=None, level=None, numeric_only=None, **kwargs
#   10801         ):
# ...

# %%
# mean weight of female players
mean_weight_women=women['Weight'].mean()
mean_weight_women
# Out:
# 151.38095238095238

# %%
table = pd.pivot_table(df, values=['Weight', 'Age'], index=['Team', 'Pos'], aggfunc={'Weight': np.mean,'Age': np.mean})
table
# Out:
#                      Age      Weight
# Team  Pos
# Men   Defence  34.800000  192.400000
#       Forward  34.357143  191.178571
#       Goalie   48.666667  196.666667
# Women Defence  45.333333  151.083333
#       Forward  34.240000  151.920000
#       Goalie   30.800000  149.400000

# %%
grouping3=men.groupby('Country')
canadian_men=grouping3.get_group('Canada')

# %%
grouping4=women.groupby('Country')
american_women=grouping4.get_group('USA')

# %%
canadian_men
# Out:
#     ID Team Country       NameF        NameL  Weight Height  \
# 6   38  Men  Canada        Karl     Stollery   181.0   5'11
# 7   39  Men  Canada       Chris          Lee   187.0    6'0
# 8   40  Men  Canada        Chay      Genoway   170.0    5'9
# 9   41  Men  Canada  Marc-Andre     Gragnani   205.0    6'3
# 10  42  Men  Canada      Stefan      Elliott   190.0    6'1
# 11  43  Men  Canada        Cody     Goloubef   200.0    6'1
# 12  44  Men  Canada         Mat     Robinson   185.0   5'10
# 13  45  Men  Canada       Maxim       Noreau   198.0    6'0
# 43  24  Men  Canada     Gilbert        Brulé   190.0   5'11
# 44  25  Men  Canada      Wojtek       Wolski   220.0    6'3
# 45  26  Men  Canada       Derek          Roy   187.0    5'9
# 46  27  Men  Canada       Chris        Kelly   194.0    6'0
# 47  28  Men  Canada         Rob  Klinkhammer   214.0    6'3
# 48  29  Men  Canada     Brandon        Kozun   170.0    5'8
# 49  30  Men  Canada     Quinton       Howden   190.0    6'2
# ...

# %%
american_women
# Out:
#     ID   Team Country     NameF               NameL  Weight Height  \
# 14  49  Women     USA     Cayla              Barnes   145.0    5'1
# 15  50  Women     USA     Kacey             Bellamy   145.0    5'7
# 16  56  Women     USA      Kali            Flanagan   142.0    5'4
# 17  58  Women     USA     Megan              Keller   160.0   5'11
# 18  64  Women     USA    Sidney               Morin   140.0    5'5
# 20  71  Women     USA       Lee           Stecklein   175.0    6'0
# 57  51  Women     USA    Hannah              Brandt   150.0    5'6
# 59  53  Women     USA   Kendall               Coyne   123.0    5'2
# 60  54  Women     USA   Brianna              Decker   150.0    5'4
# 62  59  Women     USA    Amanda              Kessel   136.0    5'5
# 63  60  Women     USA    Hilary              Knight   175.0   5'11
# 64  61  Women     USA  Jocelyne  Lamoureux-Davidson   150.0    5'6
# 65  62  Women     USA   Monique   Lamoureux-Morando   147.0    5'6
# ...

# %%
result = pd.concat([canadian_men,american_women])
result
# Out:
#     ID   Team Country       NameF               NameL  Weight Height  \
# 6   38    Men  Canada        Karl            Stollery   181.0   5'11
# 7   39    Men  Canada       Chris                 Lee   187.0    6'0
# 8   40    Men  Canada        Chay             Genoway   170.0    5'9
# 9   41    Men  Canada  Marc-Andre            Gragnani   205.0    6'3
# 10  42    Men  Canada      Stefan             Elliott   190.0    6'1
# 11  43    Men  Canada        Cody            Goloubef   200.0    6'1
# 12  44    Men  Canada         Mat            Robinson   185.0   5'10
# 13  45    Men  Canada       Maxim              Noreau   198.0    6'0
# 43  24    Men  Canada     Gilbert               Brulé   190.0   5'11
# 44  25    Men  Canada      Wojtek              Wolski   220.0    6'3
# 45  26    Men  Canada       Derek                 Roy   187.0    5'9
# 46  27    Men  Canada       Chris               Kelly   194.0    6'0
# 47  28    Men  Canada         Rob         Klinkhammer   214.0    6'3
# ...
